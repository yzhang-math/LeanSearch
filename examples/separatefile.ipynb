# %%
import re
import os
import sys
from pathlib import Path

def extract_theorems(lean_file_path):
    """
    Extract theorems from a Lean file and create separate files for each theorem.
    Each file will be named after the theorem and have "--@funsearch.run" added before
    the theorem declaration.
    
    Args:
        lean_file_path (str): Path to the Lean file
    """
    # Read the content of the Lean file
    with open(lean_file_path, 'r') as file:
        content = file.read()
    
    # Define a pattern to match theorem declarations with various complex forms
    # This handles:
    # 1. Basic "theorem name : type := by" pattern
    # 2. Complex parameter lists with parentheses, including type parameters
    # 3. Unicode symbols and various Lean-specific notations
    theorem_pattern = r'(theorem\s+([A-Za-z0-9_]+)(?:\s+[\(]?[^:]*)?(?:\s*:[\s\S]*?)(?=\s*theorem|\Z))'
    
    # Find all theorems in the file
    theorems = re.findall(theorem_pattern, content)
    
    if not theorems:
        print(f"No theorems found in {lean_file_path}")
        return
    
    # Create a directory for the output files
    output_dir = Path(lean_file_path).parent / "theorems"
    os.makedirs(output_dir, exist_ok=True)
    
    # Extract each theorem into a separate file
    for theorem_match in theorems:
        full_theorem = theorem_match[0]
        theorem_name = theorem_match[1]
        
        # Create a new file with the theorem name
        output_file_path = output_dir / f"{theorem_name}.lean"
        
        # Extract any imports or other necessary preamble from the original file
        preamble_pattern = r'^(import[\s\S]*?)(?=theorem)'
        preamble_match = re.search(preamble_pattern, content)
        preamble = preamble_match.group(1) if preamble_match else ""
        
        # Add the header and write to the new file
        with open(output_file_path, 'w') as output_file:
            #output_file.write(preamble)
            output_file.write("--@funsearch.evolve\n")
            output_file.write(full_theorem)
            output_file.write("\n\n--@funsearch.run\ntheorem irrelevant : 2 + 3 = 3 + 2 := by\n   sorry\n")
        
        print(f"Created {output_file_path}")

def main():
    extract_theorems("minif2ftest/minif2f_test.lean")

if __name__ == "__main__":
    main()
# Out:
# Created minif2ftest/theorems/mathd_algebra_478.lean
# Created minif2ftest/theorems/numbertheory_4x3m7y3neq2003.lean
# Created minif2ftest/theorems/aime_1983_p1.lean
# Created minif2ftest/theorems/amc12_2001_p5.lean
# Created minif2ftest/theorems/mathd_algebra_141.lean
# Created minif2ftest/theorems/mathd_numbertheory_3.lean
# Created minif2ftest/theorems/imo_1969_p2.lean
# Created minif2ftest/theorems/mathd_algebra_44.lean
# Created minif2ftest/theorems/mathd_algebra_209.lean
# Created minif2ftest/theorems/mathd_numbertheory_1124.lean
# Created minif2ftest/theorems/imo_1983_p6.lean
# Created minif2ftest/theorems/mathd_numbertheory_237.lean
# Created minif2ftest/theorems/mathd_algebra_33.lean
# Created minif2ftest/theorems/amc12b_2021_p3.lean
# Created minif2ftest/theorems/mathd_numbertheory_299.lean
# Created minif2ftest/theorems/amc12b_2020_p2.lean
# Created minif2ftest/theorems/algebra_sqineq_unitcircatbpabsamblt1.lean
# Created minif2ftest/theorems/imo_1977_p6.lean
# Created minif2ftest/theorems/mathd_algebra_419.lean
# Created minif2ftest/theorems/amc12a_2020_p10.lean
# Created minif2ftest/theorems/imo_1960_p2.lean
# Created minif2ftest/theorems/mathd_numbertheory_427.lean
# Created minif2ftest/theorems/numbertheory_x5neqy2p4.lean
# Created minif2ftest/theorems/mathd_algebra_398.lean
# Created minif2ftest/theorems/imo_1963_p5.lean
# Created minif2ftest/theorems/mathd_numbertheory_430.lean
# Created minif2ftest/theorems/mathd_algebra_459.lean
# Created minif2ftest/theorems/induction_12dvd4expnp1p20.lean
# Created minif2ftest/theorems/mathd_algebra_320.lean
# Created minif2ftest/theorems/mathd_algebra_137.lean
# Created minif2ftest/theorems/imo_1997_p5.lean
# Created minif2ftest/theorems/mathd_numbertheory_277.lean
# Created minif2ftest/theorems/mathd_numbertheory_559.lean
# Created minif2ftest/theorems/mathd_algebra_160.lean
# Created minif2ftest/theorems/mathd_algebra_24.lean
# Created minif2ftest/theorems/mathd_algebra_176.lean
# Created minif2ftest/theorems/induction_nfactltnexpnm1ngt3.lean
# Created minif2ftest/theorems/mathd_algebra_208.lean
# Created minif2ftest/theorems/mathd_numbertheory_353.lean
# Created minif2ftest/theorems/numbertheory_notEquiv2i2jasqbsqdiv8.lean
# Created minif2ftest/theorems/mathd_algebra_156.lean
# Created minif2ftest/theorems/mathd_numbertheory_12.lean
# Created minif2ftest/theorems/mathd_numbertheory_345.lean
# Created minif2ftest/theorems/mathd_numbertheory_447.lean
# Created minif2ftest/theorems/mathd_numbertheory_328.lean
# Created minif2ftest/theorems/mathd_numbertheory_451.lean
# Created minif2ftest/theorems/aime_1997_p9.lean
# Created minif2ftest/theorems/algebra_sqineq_at2malt1.lean
# Created minif2ftest/theorems/algebra_apbmpcneq0_aeq0anbeq0anceq0.lean
# Created minif2ftest/theorems/mathd_algebra_171.lean
# Created minif2ftest/theorems/mathd_numbertheory_227.lean
# Created minif2ftest/theorems/mathd_algebra_188.lean
# Created minif2ftest/theorems/mathd_numbertheory_765.lean
# Created minif2ftest/theorems/imo_1959_p1.lean
# Created minif2ftest/theorems/mathd_numbertheory_175.lean
# Created minif2ftest/theorems/numbertheory_fxeq4powxp6powxp9powx_f2powmdvdf2pown.lean
# Created minif2ftest/theorems/imo_1992_p1.lean
# Created minif2ftest/theorems/imo_1982_p1.lean
# Created minif2ftest/theorems/aime_1987_p5.lean
# Created minif2ftest/theorems/mathd_algebra_346.lean
# Created minif2ftest/theorems/mathd_algebra_487.lean
# Created minif2ftest/theorems/mathd_numbertheory_728.lean
# Created minif2ftest/theorems/mathd_algebra_184.lean
# Created minif2ftest/theorems/mathd_numbertheory_552.lean
# Created minif2ftest/theorems/amc12b_2021_p9.lean
# Created minif2ftest/theorems/aime_1994_p3.lean
# Created minif2ftest/theorems/mathd_algebra_215.lean
# Created minif2ftest/theorems/mathd_numbertheory_293.lean
# Created minif2ftest/theorems/mathd_numbertheory_769.lean
# Created minif2ftest/theorems/mathd_algebra_452.lean
# Created minif2ftest/theorems/mathd_numbertheory_5.lean
# Created minif2ftest/theorems/mathd_numbertheory_207.lean
# Created minif2ftest/theorems/mathd_numbertheory_342.lean
# Created minif2ftest/theorems/mathd_numbertheory_483.lean
# Created minif2ftest/theorems/amc12b_2020_p21.lean
# Created minif2ftest/theorems/amc12a_2003_p5.lean
# Created minif2ftest/theorems/mathd_numbertheory_495.lean
# Created minif2ftest/theorems/mathd_algebra_296.lean
# Created minif2ftest/theorems/algebra_abpbcpcageq3_sumaonsqrtapbgeq3onsqrt2.lean
# Created minif2ftest/theorems/algebra_2varlineareq_fp3zeq11_3tfm1m5zeqn68_feqn10_zeq7.lean
# Created minif2ftest/theorems/mathd_numbertheory_247.lean
# Created minif2ftest/theorems/induction_pord1p1on2powklt5on2.lean
# Created minif2ftest/theorems/mathd_algebra_107.lean
# Created minif2ftest/theorems/numbertheory_2pownm1prime_nprime.lean
# Created minif2ftest/theorems/mathd_algebra_412.lean
# Created minif2ftest/theorems/amc12a_2013_p4.lean
# Created minif2ftest/theorems/mathd_algebra_392.lean
# Created minif2ftest/theorems/mathd_numbertheory_314.lean
# Created minif2ftest/theorems/induction_prod1p1onk3le3m1onn.lean
# Created minif2ftest/theorems/mathd_numbertheory_343.lean
# Created minif2ftest/theorems/mathd_algebra_756.lean
# Created minif2ftest/theorems/amc12b_2002_p7.lean
# Created minif2ftest/theorems/mathd_algebra_80.lean
# Created minif2ftest/theorems/mathd_numbertheory_457.lean
# Created minif2ftest/theorems/amc12_2000_p12.lean
# Created minif2ftest/theorems/mathd_numbertheory_135.lean
# Created minif2ftest/theorems/mathd_algebra_275.lean
# Created minif2ftest/theorems/mathd_algebra_388.lean
# Created minif2ftest/theorems/amc12a_2020_p7.lean
# Created minif2ftest/theorems/induction_sumkexp3eqsumksq.lean
# Created minif2ftest/theorems/imo_1981_p6.lean
# Created minif2ftest/theorems/mathd_algebra_263.lean
# Created minif2ftest/theorems/mathd_numbertheory_34.lean
# Created minif2ftest/theorems/mathd_numbertheory_764.lean
# Created minif2ftest/theorems/amc12b_2021_p4.lean
# Created minif2ftest/theorems/imo_1962_p2.lean
# Created minif2ftest/theorems/mathd_algebra_170.lean
# Created minif2ftest/theorems/mathd_algebra_432.lean
# Created minif2ftest/theorems/mathd_algebra_598.lean
# Created minif2ftest/theorems/algebra_bleqa_apbon2msqrtableqambsqon8b.lean
# Created minif2ftest/theorems/mathd_algebra_276.lean
# Created minif2ftest/theorems/amc12a_2021_p14.lean
# Created minif2ftest/theorems/algebra_sum1onsqrt2to1onsqrt10000lt198.lean
# Created minif2ftest/theorems/mathd_numbertheory_618.lean
# Created minif2ftest/theorems/amc12a_2020_p4.lean
# Created minif2ftest/theorems/amc12b_2020_p6.lean
# Created minif2ftest/theorems/mathd_numbertheory_435.lean
# Created minif2ftest/theorems/algebra_others_exirrpowirrrat.lean
# Created minif2ftest/theorems/mathd_algebra_427.lean
# Created minif2ftest/theorems/mathd_algebra_76.lean
# Created minif2ftest/theorems/mathd_numbertheory_99.lean
# Created minif2ftest/theorems/algebra_9onxpypzleqsum2onxpy.lean
# Created minif2ftest/theorems/mathd_numbertheory_233.lean
# Created minif2ftest/theorems/algebra_absapbon1pabsapbleqsumabsaon1pabsa.lean
# Created minif2ftest/theorems/imo_1984_p6.lean
# Created minif2ftest/theorems/imo_2001_p6.lean
# Created minif2ftest/theorems/mathd_numbertheory_321.lean
# Created minif2ftest/theorems/mathd_algebra_17.lean
# Created minif2ftest/theorems/mathd_algebra_153.lean
# Created minif2ftest/theorems/algebra_sqineq_unitcircatbpamblt1.lean
# Created minif2ftest/theorems/amc12a_2021_p18.lean
# Created minif2ftest/theorems/mathd_algebra_329.lean
# Created minif2ftest/theorems/induction_pprime_pdvdapowpma.lean
# Created minif2ftest/theorems/amc12a_2021_p9.lean
# Created minif2ftest/theorems/aime_1984_p1.lean
# Created minif2ftest/theorems/amc12a_2021_p22.lean
# Created minif2ftest/theorems/mathd_numbertheory_229.lean
# Created minif2ftest/theorems/mathd_numbertheory_100.lean
# Created minif2ftest/theorems/mathd_algebra_313.lean
# Created minif2ftest/theorems/amc12b_2002_p4.lean
# Created minif2ftest/theorems/amc12a_2002_p6.lean
# Created minif2ftest/theorems/amc12a_2003_p23.lean
# Created minif2ftest/theorems/mathd_algebra_129.lean
# Created minif2ftest/theorems/amc12b_2021_p18.lean
# Created minif2ftest/theorems/mathd_algebra_484.lean
# Created minif2ftest/theorems/mathd_numbertheory_551.lean
# Created minif2ftest/theorems/mathd_algebra_304.lean
# Created minif2ftest/theorems/amc12a_2021_p8.lean
# Created minif2ftest/theorems/algebra_ineq_nto1onlt2m1on.lean
# Created minif2ftest/theorems/amc12b_2002_p19.lean
# Created minif2ftest/theorems/mathd_numbertheory_341.lean
# Created minif2ftest/theorems/mathd_numbertheory_711.lean
# Created minif2ftest/theorems/amc12b_2020_p22.lean
# Created minif2ftest/theorems/mathd_algebra_113.lean
# Created minif2ftest/theorems/amc12a_2020_p9.lean
# Created minif2ftest/theorems/amc12_2000_p1.lean
# Created minif2ftest/theorems/amc12a_2021_p19.lean
# Created minif2ftest/theorems/algebra_amgm_sumasqdivbgeqsuma.lean
# Created minif2ftest/theorems/mathd_numbertheory_212.lean
# Created minif2ftest/theorems/mathd_numbertheory_320.lean
# Created minif2ftest/theorems/mathd_algebra_125.lean
# Created minif2ftest/theorems/induction_1pxpownlt1pnx.lean
# Created minif2ftest/theorems/mathd_algebra_148.lean
# Created minif2ftest/theorems/amc12a_2019_p12.lean
# Created minif2ftest/theorems/induction_11div10tonmn1ton.lean
# Created minif2ftest/theorems/algebra_amgm_sum1toneqn_prod1tonleq1.lean
# Created minif2ftest/theorems/imo_1985_p6.lean
# Created minif2ftest/theorems/amc12a_2020_p15.lean
# Created minif2ftest/theorems/mathd_algebra_332.lean
# Created minif2ftest/theorems/algebra_cubrtrp1oncubrtreq3_rcubp1onrcubeq5778.lean
# Created minif2ftest/theorems/mathd_algebra_293.lean
# Created minif2ftest/theorems/mathd_algebra_440.lean
# Created minif2ftest/theorems/mathd_numbertheory_254.lean
# Created minif2ftest/theorems/amc12_2000_p6.lean
# Created minif2ftest/theorems/aime_1988_p8.lean
# Created minif2ftest/theorems/mathd_algebra_114.lean
# Created minif2ftest/theorems/imo_2019_p1.lean
# Created minif2ftest/theorems/mathd_algebra_513.lean
# Created minif2ftest/theorems/mathd_algebra_143.lean
# Created minif2ftest/theorems/mathd_algebra_354.lean
# Created minif2ftest/theorems/aime_1984_p7.lean
# Created minif2ftest/theorems/mathd_algebra_246.lean
# Created minif2ftest/theorems/aime_1983_p3.lean
# Created minif2ftest/theorems/numbertheory_3pow2pownm1mod2pownp3eq2pownp2.lean
# Created minif2ftest/theorems/mathd_numbertheory_85.lean
# Created minif2ftest/theorems/amc12_2001_p21.lean
# Created minif2ftest/theorems/mathd_numbertheory_239.lean
# Created minif2ftest/theorems/amc12b_2002_p2.lean
# Created minif2ftest/theorems/mathd_algebra_196.lean
# Created minif2ftest/theorems/mathd_algebra_342.lean
# Created minif2ftest/theorems/mathd_numbertheory_517.lean
# Created minif2ftest/theorems/amc12a_2009_p7.lean
# Created minif2ftest/theorems/mathd_algebra_270.lean
# Created minif2ftest/theorems/amc12a_2021_p12.lean
# Created minif2ftest/theorems/mathd_algebra_362.lean
# Created minif2ftest/theorems/mathd_numbertheory_521.lean
# Created minif2ftest/theorems/amc12a_2002_p13.lean
# Created minif2ftest/theorems/imo_1964_p2.lean
# Created minif2ftest/theorems/mathd_algebra_289.lean
# Created minif2ftest/theorems/amc12a_2021_p3.lean
# Created minif2ftest/theorems/amc12a_2008_p25.lean
# Created minif2ftest/theorems/algebra_apbpceq2_abpbcpcaeq1_aleq1on3anbleq1ancleq4on3.lean
# Created minif2ftest/theorems/mathd_numbertheory_66.lean
# Created minif2ftest/theorems/amc12b_2021_p1.lean
# Created minif2ftest/theorems/algebra_apbon2pownleqapownpbpowon2.lean
# Created minif2ftest/theorems/imo_1968_p5_1.lean
# Created minif2ftest/theorems/aime_1990_p15.lean
# Created minif2ftest/theorems/mathd_numbertheory_235.lean
# Created minif2ftest/theorems/amc12b_2020_p13.lean
# Created minif2ftest/theorems/amc12b_2021_p13.lean
# Created minif2ftest/theorems/mathd_numbertheory_234.lean
# Created minif2ftest/theorems/numbertheory_aoddbdiv4asqpbsqmod8eq1.lean
# Created minif2ftest/theorems/mathd_numbertheory_222.lean
# Created minif2ftest/theorems/aime_1999_p11.lean
# Created minif2ftest/theorems/mathd_algebra_359.lean
# Created minif2ftest/theorems/imo_1965_p2.lean
# Created minif2ftest/theorems/mathd_algebra_288.lean
# Created minif2ftest/theorems/mathd_numbertheory_127.lean
# Created minif2ftest/theorems/imo_1974_p3.lean
# Created minif2ftest/theorems/aime_1991_p9.lean
# Created minif2ftest/theorems/amc12a_2009_p6.lean
# Created minif2ftest/theorems/mathd_algebra_158.lean
# Created minif2ftest/theorems/algebra_absxm1pabsxpabsxp1eqxp2_0leqxleq1.lean
# Created minif2ftest/theorems/aime_1990_p4.lean
# Created minif2ftest/theorems/mathd_numbertheory_541.lean
# Created minif2ftest/theorems/mathd_algebra_314.lean
# Created minif2ftest/theorems/imosl_2007_algebra_p6.lean
# Created minif2ftest/theorems/amc12_2000_p20.lean
# Created minif2ftest/theorems/mathd_algebra_302.lean
# Created minif2ftest/theorems/aime_1983_p2.lean
# Created minif2ftest/theorems/mathd_algebra_139.lean
# Created minif2ftest/theorems/amc12a_2021_p25.lean
# Created minif2ftest/theorems/amc12a_2020_p25.lean
# Created minif2ftest/theorems/mathd_numbertheory_150.lean
# Created minif2ftest/theorems/aime_1989_p8.lean
# Created minif2ftest/theorems/mathd_numbertheory_296.lean
# Created minif2ftest/theorems/mathd_algebra_142.lean
# Created minif2ftest/theorems/numbertheory_exk2powkeqapb2mulbpa2_aeq1.lean
# Created minif2ftest/theorems/mathd_algebra_400.lean
# Created minif2ftest/theorems/aime_1995_p7.lean
# Created minif2ftest/theorems/mathd_numbertheory_185.lean
# Created minif2ftest/theorems/mathd_algebra_441.lean
# Created minif2ftest/theorems/mathd_numbertheory_582.lean
# Created minif2ftest/theorems/mathd_algebra_338.lean
